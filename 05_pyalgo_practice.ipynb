# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Algorithmic Trading

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## Oanda Platform

# %%
# !git clone https://github.com/tpq-classes/python_for_algo_trading_practice.git
import sys
sys.path.append('python_for_algo_trading_practice')

# %%
import numpy as np
import pandas as pd

# %%
from pylab import plt
plt.style.use('seaborn-v0_8')
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## Oanda Demo Account

# %% [markdown]
# A demo account with **Oanda UK** is needed to use the REST-API v20 with Oanda. Therefore, you need to register, for example, by using a Virtual Private Network (VPN) Provider to sign up for such an account (e.g. when you are located withing the EU).
#
# The URL is https://oanda.com/uk-en/trading. Then follow the link "Try demo" (to https://oanda.com/apply/demo/).

# %% [markdown]
# When you log in to the account (in the "Client Zone"), you land at https://hub.oanda.com. On that page, you find yout **account id** which usually starts with 101-...
#
# On the top left, you see a button "Tools". Click on it and then click on "API". Another page opens where you can create (revoke) an **access token** for the API.

# %% [markdown]
# ## `tpqoa` Package

# %% [markdown]
# For what follows, you need to install the `tpqoa` package:
#
#     pip install --upgrade git+https://github.com/yhilpisch/tpqoa.git

# %%
# !pip install --upgrade git+https://github.com/yhilpisch/tpqoa.git

# %% [markdown]
# ## Configuration File

# %% [markdown]
# You need to create a **configuration file** with your account ID and the access token for the demo account as follows:
#
#     [oanda]
#     access_token = c71f59_YOURACCESSTOKEN_13da5b8f60fac1397232
#     account_id = 101-004-YOURACCOUNTID-001
#     account_type = practice
#
# Save the file under `oanda.cfg`.

# %% [markdown]
# ## API Connection

# %%
import tpqoa  # wrapper package for the Oanda v20 REST API

# %%
api = tpqoa.tpqoa('../../../oanda.cfg')  # adjust path as needed

# %%
api.get_instruments()[-7:]

# %% [markdown]
# ## Historical Data

# %%
instrument = 'BCO_USD'
start = '2023-1-1'
end = '2023-6-28'
granularity = 'D'
price = 'M'

# %%
raw = api.get_history(instrument, start, end, granularity, price)

# %%
raw.info()

# %%
raw.head()

# %%
raw.tail()

# %%
raw['c'].plot();

# %%
instrument = 'BCO_USD'
start = '2010-1-1'
end = '2023-6-28'
granularity = 'D'
price = 'M'

# %%
raw = api.get_history(instrument, start, end, granularity, price)

# %%
raw.info()

# %%
instrument = 'EUR_USD'
start = '2023-1-1'
end = '2023-6-28'
granularity = 'H1'
price = 'M'

# %%
raw = api.get_history(instrument, start, end, granularity, price)

# %%
raw.info()

# %%
raw.head()

# %%
raw.tail()

# %%
raw['c'].plot();

# %%
# api.get_history?

# %%
instrument = 'EUR_USD'
start = '2023-6-20'
end = '2023-6-28'
granularity = 'S5'
price = 'M'

# %%
raw = api.get_history(instrument, start, end, granularity, price)

# %%
raw.info()

# %%
raw['c'].plot();

# %%
raw['c'].plot(style='r.');

# %% [markdown]
# ## Streaming Data

# %%
# api.stream_data?

# %%
api.stream_data('BCO_USD', stop=10)

# %%
api.stream_data('EUR_USD', stop=10)

# %%
api.stream_data('BTC_USD', stop=10)

# %%
api.stream_data('SPX500_USD', stop=10)

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
