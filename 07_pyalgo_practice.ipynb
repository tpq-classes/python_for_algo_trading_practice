# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Algorithmic Trading

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## Oanda Platform

# %%
# !git clone https://github.com/tpq-classes/python_for_algo_trading_practice.git
import sys
sys.path.append('python_for_algo_trading_practice')

# %%
# !pip install --upgrade git+https://github.com/yhilpisch/tpqoa.git

# %%
import numpy as np
import pandas as pd

# %%
from pylab import plt
plt.style.use('seaborn-v0_8')
# %config InlineBackend.figure_format = 'svg'
import warnings as w
w.simplefilter('ignore')

# %% [markdown]
# ## API Connection

# %%
import tpqoa  # wrapper package for the Oanda v20 REST API

# %%
api = tpqoa.tpqoa('/content/python_for_algo_trading_practice/oanda_.cfg')  # adjust path as needed

# %%
api.get_instruments()[-7:]

# %% [markdown]
# ## Streaming Data

# %%
api.stream_data('EUR_USD', stop=10)

# %%
api.stream_data('BCO_USD', stop=10)

# %%
# api.stream_data??

# %%
api.on_success??

# %%
class OLSTrader(tpqoa.tpqoa):
    def on_success(self, time, bid, ask):
        print(bid, time, ask)
        #
        # Implement trading logic here.
        #

# %%
ols = OLSTrader('/content/python_for_algo_trading_practice/oanda_.cfg')

# %%
ols.stream_data('BCO_USD', stop=7)

# %% [markdown]
# ## Placing Trades

# %%
api.create_order('BCO_USD', units=10)

# %%
api.create_order('BCO_USD', units=-10)

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
